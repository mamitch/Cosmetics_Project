# %%
import requests
from bs4 import BeautifulSoup

import pandas as pd

# %%
# scrape all 19 pages to get names and urls

# names = []
# urls = []

# go to each page (print progress)
# for i in range(1, 19):
url = 'https://www.beautycounter.com/products/makeup' #+ str(i)
page = requests.get(url)
print (page)

soup = BeautifulSoup(page.content, 'html.parser')
    
    #in each page, scrape the names
#     for j in soup.findAll('span', class_='title product-name-custom'):
#         names.append(j.get_text())
#     for k in soup.findAll(itemprop = 'url'):
#         urls.append(k.get('href'))
# Out:
# <Response [200]>

# %%
names=[]

lum = soup.find('div', class_="_2VEr2" )

# %%
print(soup.prettify("utf-8"))
# Out:
# b'<!DOCTYPE html>\n<html class="no-js" lang="en-US">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="ie=edge" http-equiv="x-ua-compatible"/>\n  <title>\n  </title>\n  <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=5.0" name="viewport"/>\n  <meta content="browserconfig.xml" name="msapplication-config"/>\n  <link href="/manifest.json" rel="manifest"/>\n  <link href="https://assets.beautycounter.com" rel="dns-prefetch"/>\n  <link href="//images.beautycounter.com" rel="dns-prefetch"/>\n  <link href="//images.ctfassets.net" rel="dns-prefetch"/>\n  <link href="//www.googleapis.com" rel="dns-prefetch"/>\n  <link href="//cdn.contentful.com" rel="dns-prefetch"/>\n  <link href="https://www.beautycounter.com/products/makeup" rel="canonical"/>\n  <link href="https://www.beautycounter.com/products/makeup" hreflang="x-default" rel="alternate"/>\n  <link href="https://www.beautycounter.com/products/makeup" hreflang="en-us" rel="alternate"/>\n  <link hre
# ...

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype, bs4.element.Tag]

# %%
html= list(soup.children)[1]

# %%
html.find_all('a', "_1-Uu8")
# Out:
# []

# %%
from selenium.webdriver import Chrome
driver = Chrome('/Users/mmitchell3/Downloads/chromedriver')
driver.get('https://www.beautycounter.com/products/makeup')

# %%
element = driver.find_element_by_xpath('//*[@id="product-list"]/div[3]/div[2]/div[1]/div/header/div[1]/span/a')

# %%
el_url = element.get_attribute('href')

# %%
driver.get(el_url)

# %%
page = driver.find_element_by_xpath('//*[@id="main-content"]')

# %%
page_contents = page.text

# %%
page_contents
# Out:
# "Give 'Em Lip Trio\nITEM #100000594\n77 reviews\nNEW\n$75\nSIZE: 3.6 G/ .12 OZ X3\n1\n2\n3\n4\n5\n6\n7\n8\nADD TO BAG\n\n\n\n\nSHARE:\nDESCRIPTION\nThree limited-edition lipsticks. One major statement.\nWe’re celebrating our seventh anniversary of pioneering clean beauty and advocating for a safer future with three powerful lipsticks. They’re more than just perfect shades, creamy textures, and pretty tubes—they’re catalysts for change.\n\nCOLOR INTENSE LIPSTICK\nDelivers the rich color payoff and luxe satin finish you want, with the safety you deserve.\nCreamy, long-wearing formula moisturizes so lips feel soft and smooth, never dry and uncomfortable.\nNatural peppermint oil delivers a subtly refreshing flavor.\n\nGIVE ‘EM LIP\nBold shades deserve bold art. We partnered with Portland-based artist Lisa Congdon to create our limited-edition packaging.\nBy using a paper lipstick tube rather than standard aluminum, we’re reducing our environmental impact* by 83% per tube.\nThe tube is ma
# ...

# %%
page_contents_list = page_contents.split('\n')

# %%
name = page_contents_list[0]
price = page_contents_list[4]
description = page_contents_list[21:33]
seperator= ' '
description = seperator.join(description)

# %%
page_contents_list.index( 'The tube is made with FSC-certified paper—meaning it comes from responsibly managed forests.')
# Out:
# 32

# %%
page_contents_list
# Out:
# ["Give 'Em Lip Trio",
#  'ITEM #100000594',
#  '77 reviews',
#  'NEW',
#  '$75',
#  'SIZE: 3.6 G/ .12 OZ X3',
#  '1',
#  '2',
#  '3',
#  '4',
#  '5',
#  '6',
#  '7',
#  '8',
#  'ADD TO BAG',
#  '',
#  '',
#  '',
#  '',
#  'SHARE:',
#  'DESCRIPTION',
#  'Three limited-edition lipsticks. One major statement.',
#  'We’re celebrating our seventh anniversary of pioneering clean beauty and advocating for a safer future with three powerful lipsticks. They’re more than just perfect shades, creamy textures, and pretty tubes—they’re catalysts for change.',
#  '',
#  'COLOR INTENSE LIPSTICK',
#  'Delivers the rich color payoff and luxe satin finish you want, with the safety you deserve.',
#  'Creamy, long-wearing formula moisturizes so lips feel soft and smooth, never dry and uncomfortable.',
#  'Natural peppermint oil delivers a subtly refreshing flavor.',
#  '',
#  'GIVE ‘EM LIP',
# ...

# %%
driver.quit()
